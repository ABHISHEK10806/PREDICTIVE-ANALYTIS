# %% [markdown]
# ## 1. 📥 Libraries Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2. 📂 Load Dataset

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-30409203-bb91-4719-9128-b71294bff404" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-30409203-bb91-4719-9128-b71294bff404">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ##3. 🔹 Read CSV File

# %%
df = pd.read_csv("ind_nifty50list.csv")

# %% [markdown]
# ## 4. 👀 Basic Inspection

# %%
df.head()
# Out:
#                                  Company Name            Industry      Symbol  \
# 0                      Adani Enterprises Ltd.     Metals & Mining    ADANIENT
# 1  Adani Ports and Special Economic Zone Ltd.            Services  ADANIPORTS
# 2            Apollo Hospitals Enterprise Ltd.          Healthcare  APOLLOHOSP
# 3                           Asian Paints Ltd.   Consumer Durables  ASIANPAINT
# 4                              Axis Bank Ltd.  Financial Services    AXISBANK
#
#   Series     ISIN Code
# 0     EQ  INE423A01024
# 1     EQ  INE742F01042
# 2     EQ  INE437A01024
# 3     EQ  INE021A01026
# 4     EQ  INE238A01034

# %%
df.tail()
# Out:
#              Company Name                Industry      Symbol Series  \
# 45     Tech Mahindra Ltd.  Information Technology       TECHM     EQ
# 46     Titan Company Ltd.       Consumer Durables       TITAN     EQ
# 47             Trent Ltd.       Consumer Services       TRENT     EQ
# 48  UltraTech Cement Ltd.  Construction Materials  ULTRACEMCO     EQ
# 49             Wipro Ltd.  Information Technology       WIPRO     EQ
#
#        ISIN Code
# 45  INE669C01036
# 46  INE280A01028
# 47  INE849A01020
# 48  INE481G01011
# 49  INE075A01022

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company Name  50 non-null     object
#  1   Industry      50 non-null     object
#  2   Symbol        50 non-null     object
#  3   Series        50 non-null     object
#  4   ISIN Code     50 non-null     object
# dtypes: object(5)
# memory usage: 2.1+ KB

# %%
df.describe()
# Out:
#                   Company Name            Industry    Symbol Series  \
# count                       50                  50        50     50
# unique                      50                  15        50      1
# top     Adani Enterprises Ltd.  Financial Services  ADANIENT     EQ
# freq                         1                  12         1     50
#
#            ISIN Code
# count             50
# unique            50
# top     INE423A01024
# freq               1

# %% [markdown]
# ## 5. 📅 Convert to Datetime

# %%
# df['Date'] = pd.to_datetime(df['Date'])
# df.set_index('Date', inplace=True)

# %% [markdown]
# ## **6**. 📊 Plot Time Series

# %%
plt.figure(figsize=(10,5))
plt.plot(df['ISIN Code'])
plt.title("Time Series Plot")
plt.xlabel("Series")
plt.ylabel("ISIN Code")
plt.show()

# %% [markdown]
# ## 7. 📈 Trend Analysis (Rolling Mean)

# %%
# df['Rolling_Mean'] = df['ISIN Code'].rolling(window=7).mean()

plt.figure(figsize=(10,5))
plt.plot(df['ISIN Code'], label='Original')
# plt.plot(df['Rolling_Mean'], label='Rolling Mean', color='red')
plt.legend()
plt.show()

# %% [markdown]
# ## 8. 🔁 Seasonality Check

# %%
# df['Series'] = df.index.month

sns.boxplot(x='Series', y='ISIN Code', data=df)
plt.title("Monthly Seasonality")
plt.show()

# %% [markdown]
# ##9. 🔍 Decomposition (Trend + Seasonality + Noise)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# decomposition = seasonal_decompose(df['Value'], model='additive')
# decomposition.plot()
# plt.show()
